# %% [markdown]
# <a href="https://colab.research.google.com/github/lovishdany/RL__NCU/blob/main/Lab-2__Practical-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([5,4,9,8,11])
b = np.array(10*a[::-1])

print(a)
print(b)

c = np.corrcoef(a,b)
print("")
print(c,"\n")

plt.figure(figsize=(5, 5))
plt.plot(c)
plt.title("Correlation Graph")
plt.show()
# Out:
# [ 5  4  9  8 11]
# [110  80  90  40  50]
#
# [[ 1.         -0.56626506]
#  [-0.56626506  1.        ]]

# %%
x_pos = [1, 2, 3, 4, 5, 6, 7]
y_pos = [i+1 for i in x_pos]

x_neg = [1, 2, 3, 4, 5, 6, 7]
y_neg = [x_neg[::-1]]

x_zero = np.array(np.random.randint((10),size=(20)))
y_zero = np.array(np.random.randint((10),size=(20)))

# %%
# Plotting

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.scatter(x_pos, y_pos, color='blue')
plt.title("Positive Correlation")

plt.subplot(1, 3, 2)
plt.scatter(x_neg, y_neg, color='red')
plt.title("Negative Correlation")

plt.subplot(1, 3, 3)
plt.scatter(x_zero, y_zero, color='green')
plt.title("Zero Correlation")

plt.tight_layout()
plt.show()

# %%
arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))

plt.scatter(arr1,arr2)

# %%
rel = np.corrcoef(arr1,arr2)
print(rel)
plt.plot(rel)
# Out:
# [[ 1.         -0.00322219]
#  [-0.00322219  1.        ]]
# [<matplotlib.lines.Line2D at 0x7c712dad6620>,
#  <matplotlib.lines.Line2D at 0x7c712dad6680>]

# %%
arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))
arr3 = np.array(np.random.choice((-(arr1*75)), size=(500)))
arr4 = np.array(np.random.randint((1000), size=(500)))

import pandas as pd

df = pd.DataFrame({"A":arr1, "B":arr2, "C":arr3, "D":arr4})

df
# Out:
#        A      B      C    D
# 0    942  22914 -36600  974
# 1    205  48393 -55200  209
# 2    372  17670 -16650  501
# 3    820   7239 -67200  181
# 4    940  20064 -30225  522
# ..   ...    ...    ...  ...
# 495  386  22002 -45375  692
# 496  322   5586 -48450  815
# 497  232  45030 -34275  242
# 498   97  27417 -27900  217
# 499  246  19950 -74250  789
#
# [500 rows x 4 columns]

# %%
corr = df.corr(method='pearson')
corr
# Out:
#           A         B         C         D
# A  1.000000  0.041053  0.004726  0.019575
# B  0.041053  1.000000 -0.079139  0.026986
# C  0.004726 -0.079139  1.000000 -0.070026
# D  0.019575  0.026986 -0.070026  1.000000
