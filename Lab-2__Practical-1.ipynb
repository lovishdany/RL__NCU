# %% [markdown]
# <a href="https://colab.research.google.com/github/lovishdany/RL__NCU/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([5,4,9,8,11])
b = np.array([10,45,60,50,90])

print(a)
print(b)

c = np.corrcoef(a,b)
print("")
print(c)

plt.plot(a,b)
# Out:
# [ 5  4  9  8 11]
# [10 45 60 50 90]
#
# [[1.         0.82228916]
#  [0.82228916 1.        ]]

# %%
import matplotlib.pyplot as plt

plt.plot(c)

# %%
plt.scatter(a,b)

# %%
arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))

plt.scatter(arr1,arr2)

# %%
rel = np.corrcoef(arr1,arr2)
print(rel)
plt.plot(rel)
# Out:
# [[ 1.         -0.01154032]
#  [-0.01154032  1.        ]]
# ...
